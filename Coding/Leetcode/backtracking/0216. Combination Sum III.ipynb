# %%
'''
216. Combination Sum III
'''
class Solution:
    def combinationSum3(self, k: int, n: int) -> List[List[int]]:
        self.result = []
        self.backtracking(k, n, [], 1)
        return self.result
    
    def backtracking(self, k, n, path, startIndex):
        if len(path) > k or sum(path) > n: return
        if len(path) == k and sum(path) == n:
            self.result.append(path[:])
            return
        for i in range(startIndex, 10):
            path.append(i)
            self.backtracking(k, n, path, i+1)
            path.pop()
        return

class Solution:
    def combinationSum3(self, k: int, n: int) -> List[List[int]]:
        self.result = []
        self.backtracking(k, n, 0, [], 1)
        return self.result
    
    def backtracking(self, k, n, curSum, path, startIndex):
        if len(path) > k or curSum > n: return
        if len(path) == k and curSum == n:
            self.result.append(path[:])
            return
        for i in range(startIndex, 10 - (k - len(path)) + 1):
            curSum += i
            path.append(i)
            self.backtracking(k, n, curSum, path, i+1)
            curSum -= i
            path.pop()
        return


class Solution:
    def combinationSum3(self, k: int, n: int) -> List[List[int]]:
        self.result = []
        self.backtracking(k, n, 0, [], 1)
        return self.result
    
    def backtracking(self, k, n, curSum, path, startIndex):
        if len(path) > k or curSum > n: return
        if len(path) == k and curSum == n:
            self.result.append(path[:])
            return
        for i in range(startIndex, 10):
            curSum += i
            path.append(i)
            self.backtracking(k, n, curSum, path, i+1)
            curSum -= i
            path.pop()
        return
