# %%
import re

file1 = open("regex_1.txt")
file2 = open("regex_2.txt")

result = 0
for line in file2:
    numbers = re.findall('[0-9]+', line)
    if len(numbers) == 0: continue
    result += sum(map(int, numbers))
    
print(result)
# Out:
# 241887

# %% [markdown]
# Change String list -> Int list: map(int, str_list)

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1: break
    print(data.decode())

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Sun, 10 Dec 2023 23:04:21 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/intro-short.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1: break
    print(data.decode())

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Sun, 10 Dec 2023 23:04:21 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "1d3-54f6609240717"
# Accept-Ranges: bytes
# Content-Length: 467
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Why should you learn to write programs?
#
# Writing programs (or programming) is a very creative
# and rewarding activity.  You can write programs
#  for
# many reasons, ranging from making your living to solving
# a difficult data analysis problem to having fun to helping
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program, and that once
# you know how to program you will figure out what you want
# to do with your newfound skills.

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "http://py4e-data.dr-chuck.net/comments_1942872.html"
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
tags = soup('span')
result = 0
for tag in tags:
    result += int(tag.contents[0])
    # Look at the parts of a tag
    print('TAG:', tag)
    print('URL:', tag.get('href', None))
    print('Contents:', tag.contents[0])
    print('Attrs:', tag.attrs)
    
print(result)
# Out:
# TAG: <span class="comments">99</span>
# URL: None
# Contents: 99
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">96</span>
# URL: None
# Contents: 96
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">94</span>
# URL: None
# Contents: 94
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">92</span>
# URL: None
# Contents: 92
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">90</span>
# URL: None
# Contents: 90
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">85</span>
# URL: None
# Contents: 85
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">83</span>
# URL: None
# Contents: 83
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">81</span>
# URL: None
# Contents: 81
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">78</span>
# URL: None
# Contents: 78
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">72</span>
# URL: None
# Contents: 72
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">72</span>
# URL: None
# Contents: 72
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">71</span>
# URL: None
# Contents: 71
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">70</span>
# URL: None
# Contents: 70
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">64</span>
# URL: None
# Contents: 64
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">63</span>
# URL: None
# Contents: 63
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">61</span>
# URL: None
# Contents: 61
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">54</span>
# URL: None
# Contents: 54
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">49</span>
# URL: None
# Contents: 49
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">48</span>
# URL: None
# Contents: 48
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">48</span>
# URL: None
# Contents: 48
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">47</span>
# URL: None
# Contents: 47
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">47</span>
# URL: None
# Contents: 47
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">46</span>
# URL: None
# Contents: 46
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">44</span>
# URL: None
# Contents: 44
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">44</span>
# URL: None
# Contents: 44
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">43</span>
# URL: None
# Contents: 43
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">43</span>
# URL: None
# Contents: 43
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">42</span>
# URL: None
# Contents: 42
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">42</span>
# URL: None
# Contents: 42
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">36</span>
# URL: None
# Contents: 36
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">34</span>
# URL: None
# Contents: 34
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">31</span>
# URL: None
# Contents: 31
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">29</span>
# URL: None
# Contents: 29
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">25</span>
# URL: None
# Contents: 25
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">25</span>
# URL: None
# Contents: 25
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">24</span>
# URL: None
# Contents: 24
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">21</span>
# URL: None
# Contents: 21
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">20</span>
# URL: None
# Contents: 20
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">15</span>
# URL: None
# Contents: 15
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">12</span>
# URL: None
# Contents: 12
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">10</span>
# URL: None
# Contents: 10
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">9</span>
# URL: None
# Contents: 9
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">8</span>
# URL: None
# Contents: 8
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">7</span>
# URL: None
# Contents: 7
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">7</span>
# URL: None
# Contents: 7
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">7</span>
# URL: None
# Contents: 7
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">6</span>
# URL: None
# Contents: 6
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">5</span>
# URL: None
# Contents: 5
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">5</span>
# URL: None
# Contents: 5
# Attrs: {'class': ['comments']}
# TAG: <span class="comments">3</span>
# URL: None
# Contents: 3
# Attrs: {'class': ['comments']}
# 2207

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "http://py4e-data.dr-chuck.net/known_by_Aydan.html"
pos, count = 18, 7

result = list()

for i in range(count):
    print(re.findall('by_(.+)\.', url), url)
    html = urllib.request.urlopen(url, context=ctx).read()
    soup = BeautifulSoup(html, 'html.parser')

    # Retrieve all of the anchor tags
    tags = soup('a')
    tag = tags[pos - 1]

    name = tag.string
    url = tag.get('href', None)
    print(name, url)
    result.append(name)

print(' '.join(result))
# Out:
# ['Aydan'] http://py4e-data.dr-chuck.net/known_by_Aydan.html
# Makayla http://py4e-data.dr-chuck.net/known_by_Makayla.html
# ['Makayla'] http://py4e-data.dr-chuck.net/known_by_Makayla.html
# Marie http://py4e-data.dr-chuck.net/known_by_Marie.html
# ['Marie'] http://py4e-data.dr-chuck.net/known_by_Marie.html
# Kyral http://py4e-data.dr-chuck.net/known_by_Kyral.html
# ['Kyral'] http://py4e-data.dr-chuck.net/known_by_Kyral.html
# Georgy http://py4e-data.dr-chuck.net/known_by_Georgy.html
# ['Georgy'] http://py4e-data.dr-chuck.net/known_by_Georgy.html
# Aiyanna http://py4e-data.dr-chuck.net/known_by_Aiyanna.html
# ['Aiyanna'] http://py4e-data.dr-chuck.net/known_by_Aiyanna.html
# Breeanna http://py4e-data.dr-chuck.net/known_by_Breeanna.html
# ['Breeanna'] http://py4e-data.dr-chuck.net/known_by_Breeanna.html
# Jeremy http://py4e-data.dr-chuck.net/known_by_Jeremy.html
# Makayla Marie Kyral Georgy Aiyanna Breeanna Jeremy

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "http://py4e-data.dr-chuck.net/comments_1942874.xml"

xml = urllib.request.urlopen(url, context=ctx).read()
stuff = ET.fromstring(xml)
lst = stuff.findall('.//count')
print(len(lst))

result = 0
for item in lst:
    result += int(item.text)

print(result)
# Out:
# 50
# 2343

# %%
import json
import urllib.request, urllib.parse, urllib.error
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

test_url = "http://py4e-data.dr-chuck.net/comments_42.json"
url = "http://py4e-data.dr-chuck.net/comments_1942875.json"

data = urllib.request.urlopen(url, context=ctx).read()
info = json.loads(data)
comments = info["comments"]

result = 0
for comment in comments:
    try:
        num = int(comment["count"])
    except:
        continue
    result += num

print(result)
# Out:
# 2591

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    # print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
    place_id = js["results"][0]["place_id"]
    print(place_id)
